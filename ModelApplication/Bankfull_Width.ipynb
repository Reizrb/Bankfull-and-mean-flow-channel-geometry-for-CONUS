# %% [markdown]
# ## Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import math
import seaborn as sns
from utils import Scatter_Violin_Plots, Performance_metrics, Hbar, Merge_Multiple_Files

# %% [markdown]
# ## Import dataset

# %%
# Import the training dataset
train = pd.read_csv('./DataPreProcessing/df_Train.csv', converters={'site_no': str}, low_memory=False)

# Import the testing dataset
test = pd.read_csv('./DataPreProcessing/df_Test.csv', converters={'site_no': str}, low_memory=False)

# Import the NHDPlusV2.1 dataset
NHD = pd.read_csv('./DataPreProcessing/indep_var_reaches_CONUS.txt', converters={'site_no': str}, low_memory=False)

# %%
# Spliting the dependent (y) variable and independent (X) variables for training dataset
y_train= train[['stream_wdth_va_bnk']]
## Model 1
X_train_m1= train[['q_va_bnk', 'TotDASqKM', 
                   'CAT_EVI_OND_2011', 'CAT_EVI_AMJ_2012', 'CAT_EVI_JAS_2012', 'CAT_EVI_JFM_2012',
                   'ACC_NDAMS2010', 'CAT_POPDENS10', 'StreamOrde','D50_mm_', 'Mean_AI', 
                   'NLCD_Developed_%', 'NLCD_Forest_%', 'NLCD_Agriculture_%', 
                   'MINELEVSMO', 'SLOPE', 'CAT_SILTAVE', 'CAT_CLAYAVE','CAT_SANDAVE']]
## Model 2
X_train_m2= train[['QE_cms', 'TotDASqKM', 
                   'CAT_EVI_OND_2011', 'CAT_EVI_AMJ_2012', 'CAT_EVI_JAS_2012', 'CAT_EVI_JFM_2012',
                   'ACC_NDAMS2010', 'CAT_POPDENS10', 'StreamOrde','D50_mm_', 'Mean_AI', 
                   'NLCD_Developed_%', 'NLCD_Forest_%', 'NLCD_Agriculture_%', 
                   'MINELEVSMO', 'SLOPE', 'CAT_SILTAVE', 'CAT_CLAYAVE','CAT_SANDAVE']]

# Spliting the dependent (y) variable and independent (X) variables for testing dataset
y_test= test[['stream_wdth_va_bnk']]               
## Model 1
X_test_m1= test[['q_va_bnk', 'TotDASqKM', 
                 'CAT_EVI_OND_2011', 'CAT_EVI_AMJ_2012', 'CAT_EVI_JAS_2012', 'CAT_EVI_JFM_2012',
                 'ACC_NDAMS2010', 'CAT_POPDENS10', 'StreamOrde','D50_mm_', 'Mean_AI', 
                 'NLCD_Developed_%', 'NLCD_Forest_%', 'NLCD_Agriculture_%', 
                 'MINELEVSMO', 'SLOPE', 'CAT_SILTAVE', 'CAT_CLAYAVE','CAT_SANDAVE']]
## Model 2
X_test_m2= test[['QE_cms', 'TotDASqKM', 
                 'CAT_EVI_OND_2011', 'CAT_EVI_AMJ_2012', 'CAT_EVI_JAS_2012', 'CAT_EVI_JFM_2012',
                 'ACC_NDAMS2010', 'CAT_POPDENS10', 'StreamOrde','D50_mm_', 'Mean_AI', 
                 'NLCD_Developed_%', 'NLCD_Forest_%', 'NLCD_Agriculture_%', 
                 'MINELEVSMO', 'SLOPE', 'CAT_SILTAVE', 'CAT_CLAYAVE','CAT_SANDAVE']]


# Excluding independent (X) variables for NHDPlusV2.1 dataset (Application)
df_COMID_NHD= NHD[['COMID', 'REACHCODE']] 
X_NHD= NHD[['QE_cms', 'TotDASqKM_y', 
            'CAT_EVI_OND_2011', 'CAT_EVI_AMJ_2012', 'CAT_EVI_JAS_2012', 'CAT_EVI_JFM_2012',
            'ACC_NDAMS2010', 'CAT_POPDENS10', 'StreamOrde_y','D50_mm_', 'Mean_AI', 
            'NLCD_Developed_%', 'NLCD_Forest_%', 'NLCD_Agriculture_%', 
            'MINELEVSMO', 'SLOPE', 'CAT_SILTAVE', 'CAT_CLAYAVE','CAT_SANDAVE']]

# %% [markdown]
# ## Create models

# %% [markdown]
# ### a) Make prediction on testing dataset using final MLR mode

# %%
# Model 1
m1_Intercept = 0.72883
m1_q_va_bnk = 0.28562
m1_TotDASqKM = 0.18352
m1_Mean_AI = 0.31169
m1_D50_mm_ = 0.03040
m1_NLCD_Agriculture_ = -0.01974
m1_CAT_SILTAVE = -0.08179
mlr_pred_m1 = (10**m1_Intercept) * (X_test_m1['q_va_bnk']**m1_q_va_bnk) * (X_test_m1['TotDASqKM']**m1_TotDASqKM) *(X_test_m1['Mean_AI']**m1_Mean_AI) * (X_test_m1['D50_mm_']**m1_D50_mm_) * (X_test_m1['NLCD_Agriculture_%']**m1_NLCD_Agriculture_) * (X_test_m1['CAT_SILTAVE']**m1_CAT_SILTAVE)

# Model 2
m2_Intercept = 1.0637086
m2_CAT_EVI_OND_2011 = -0.267214
m2_ACC_NDAMS2010 = 0.0291658
m2_Mean_AI = 0.1731988
m2_NLCD_Forest_ = -0.024713
m2_QE_cms = 0.3507422
mlr_pred_m2 = (10**m2_Intercept) * (X_test_m2['CAT_EVI_OND_2011']**m2_CAT_EVI_OND_2011) * (X_test_m2['ACC_NDAMS2010']**m2_ACC_NDAMS2010) *(X_test_m2['Mean_AI']**m2_Mean_AI) * (X_test_m2['NLCD_Forest_%']**m2_NLCD_Forest_) * (X_test_m2['QE_cms']**m2_QE_cms)

# %% [markdown]
# ### b) Make prediction on testing dataset using final RFR mode

# %%
# Model 1
with open('./RFR/Best_Param/bnk_width_m1_rfr', "rb") as fp:
    RFR_m1 = pickle.load(fp)
rfr_pred_m1 = RFR_m1.predict(X_test_m1.values)

# Model 2
with open('./RFR/Best_Param/bnk_width_m2_rfr', "rb") as fp:
    RFR_m2 = pickle.load(fp)
rfr_pred_m2 = RFR_m2.predict(X_test_m2.values)

# %% [markdown]
# ### c) Make prediction on testing dataset using final XGBR model

# %%
# Model 1
with open('./XGBR/Best_Param/bnk_width_m1_xgbr', "rb") as fp:
    XGBR_m1 = pickle.load(fp)
xgb_pred_m1 = XGBR_m1.predict(X_test_m1.values)

# Model 2
with open('./XGBR/Best_Param/bnk_width_m2_xgbr', "rb") as fp:
    XGBR_m2 = pickle.load(fp)
xgb_pred_m2 = XGBR_m2.predict(X_test_m2.values)

# %% [markdown]
# ## Performance Metrics

# %%
Model_names = ['XGBR', 'RFR', 'MLR']
pred_list= [[xgb_pred_m1, rfr_pred_m1, mlr_pred_m1], [xgb_pred_m2, rfr_pred_m2, mlr_pred_m2]]
Metrics = pd.DataFrame()
for i in range (0,2):
    for j in range(0,3):
        X = y_test
        Y = pred_list[i][j]
        df = pd.DataFrame({f'{Model_names[j]}': [ Performance_metrics(X, Y, "Yes")[0], Performance_metrics(X, Y, "Yes")[1], Performance_metrics(X, Y, "Yes")[2], Performance_metrics(X, Y, "Yes")[3], Performance_metrics(X, Y, "Yes")[4]]})
        Metrics= pd.concat([df, Metrics], axis=1)
    Metrics = Metrics.rename( index={  0:'R\N{SUPERSCRIPT TWO}', 1:'NSE', 2:'KGE', 3:'APB (%)',  4:'RMSE (cms)'})

# Export performance metrics for future
Metrics.to_csv('./ModelApplication/Output/W_bnk_performance_metrics.csv')

# %%
print('Perfomance Metrics Results for Model 1:')
Metrics.iloc[5:10,3:6].style
# Out:
# Perfomance Metrics Results for Model 1:
# <style type="text/css">
# </style>
# <table id="T_5444b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5444b_level0_col0" class="col_heading level0 col0" >MLR</th>
#       <th id="T_5444b_level0_col1" class="col_heading level0 col1" >RFR</th>
#       <th id="T_5444b_level0_col2" class="col_heading level0 col2" >XGBR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5444b_level0_row0" class="row_heading level0 row0" >R²</th>
#       <td id="T_5444b_row0_col0" class="data row0 col0" >0.84</td>
#       <td id="T_5444b_row0_col1" class="data row0 col1" >0.86</td>
#       <td id="T_5444b_row0_col2" class="data row0 col2" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_5444b_level0_row1" class="row_heading level0 row1" >NSE</th>
#       <td id="T_5444b_row1_col0" class="data row1 col0" >0.82</td>
#       <td id="T_5444b_row1_col1" class="data row1 col1" >0.85</td>
#       <td id="T_5444b_row1_col2" class="data row1 col2" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_5444b_level0_row2" class="row_heading level0 row2" >KGE</th>
#       <td id="T_5444b_row2_col0" class="data row2 col0" >0.75</td>
#       <td id="T_5444b_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_5444b_row2_col2" class="data row2 col2" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_5444b_level0_row3" class="row_heading level0 row3" >APB (%)</th>
#       <td id="T_5444b_row3_col0" class="data row3 col0" >27.65</td>
#       <td id="T_5444b_row3_col1" class="data row3 col1" >28.11</td>
#       <td id="T_5444b_row3_col2" class="data row3 col2" >25.58</td>
#     </tr>
#     <tr>
#       <th id="T_5444b_level0_row4" class="row_heading level0 row4" >RMSE (cms)</th>
#       <td id="T_5444b_row4_col0" class="data row4 col0" >35.01</td>
#       <td id="T_5444b_row4_col1" class="data row4 col1" >31.24</td>
#       <td id="T_5444b_row4_col2" class="data row4 col2" >30.74</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('Perfomance Metrics Results for Model 2:')
Metrics.iloc[0:5,0:3].style
# Out:
# Perfomance Metrics Results for Model 2:
# <style type="text/css">
# </style>
# <table id="T_2ea87">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ea87_level0_col0" class="col_heading level0 col0" >MLR</th>
#       <th id="T_2ea87_level0_col1" class="col_heading level0 col1" >RFR</th>
#       <th id="T_2ea87_level0_col2" class="col_heading level0 col2" >XGBR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ea87_level0_row0" class="row_heading level0 row0" >R²</th>
#       <td id="T_2ea87_row0_col0" class="data row0 col0" >0.82</td>
#       <td id="T_2ea87_row0_col1" class="data row0 col1" >0.84</td>
#       <td id="T_2ea87_row0_col2" class="data row0 col2" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_2ea87_level0_row1" class="row_heading level0 row1" >NSE</th>
#       <td id="T_2ea87_row1_col0" class="data row1 col0" >0.75</td>
#       <td id="T_2ea87_row1_col1" class="data row1 col1" >0.84</td>
#       <td id="T_2ea87_row1_col2" class="data row1 col2" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_2ea87_level0_row2" class="row_heading level0 row2" >KGE</th>
#       <td id="T_2ea87_row2_col0" class="data row2 col0" >0.61</td>
#       <td id="T_2ea87_row2_col1" class="data row2 col1" >0.84</td>
#       <td id="T_2ea87_row2_col2" class="data row2 col2" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_2ea87_level0_row3" class="row_heading level0 row3" >APB (%)</th>
#       <td id="T_2ea87_row3_col0" class="data row3 col0" >33.77</td>
#       <td id="T_2ea87_row3_col1" class="data row3 col1" >30.80</td>
#       <td id="T_2ea87_row3_col2" class="data row3 col2" >29.39</td>
#     </tr>
#     <tr>
#       <th id="T_2ea87_level0_row4" class="row_heading level0 row4" >RMSE (cms)</th>
#       <td id="T_2ea87_row4_col0" class="data row4 col0" >41.17</td>
#       <td id="T_2ea87_row4_col1" class="data row4 col1" >32.78</td>
#       <td id="T_2ea87_row4_col2" class="data row4 col2" >31.98</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Scatter and Violin plots of all models

# %%
Y = [mlr_pred_m1, rfr_pred_m1, xgb_pred_m1]
y = [mlr_pred_m2, rfr_pred_m2, xgb_pred_m2]
models = ['Bankfull Width - MLR', 'Bankfull Width - RFR', 'Bankfull Width - XGBR']
for i in range (0,3):
    Scatter_Violin_Plots(y_test, Y[i], y[i], "Observation (m)", "Prediction (m)",  "Value (m)", "Model 1", "Model 2", models[i])

# %% [markdown]
# ## Apply hybrid approcah coupling MLR and XGBR to NHDPlus dataset

# %%
# Make prediction on NHDPlusV2.1 dataset using final XGBR model
xgb_pred_NHD0 = pd.DataFrame(XGBR_m2.predict(X_NHD))
xgb_pred_NHD0.columns = ['W_bnk_PRE_NHD_xgb']
W_bnk = Merge_Multiple_Files([df_COMID_NHD, X_NHD, xgb_pred_NHD0], None)

# If predicted value is negative, apply MLR for predictionW_bnk
W_bnk.loc[W_bnk['W_bnk_PRE_NHD_xgb'] < 0, 'W_bnk_PRE_NHD_final'] = (10**m2_Intercept) * (W_bnk['CAT_EVI_OND_2011']**m2_CAT_EVI_OND_2011) * (W_bnk['ACC_NDAMS2010']**m2_ACC_NDAMS2010) *(W_bnk['Mean_AI']**m2_Mean_AI) * (W_bnk['NLCD_Forest_%']**m2_NLCD_Forest_) * (W_bnk['QE_cms']**m2_QE_cms) 
W_bnk.loc[W_bnk['W_bnk_PRE_NHD_xgb'] < 0, 'xgb_or_mlr'] = 'mlr'

# If predicted value is equal or greater than zero, keep the predicted value through XGBR
W_bnk.loc[W_bnk['W_bnk_PRE_NHD_xgb'] >= 0, 'W_bnk_PRE_NHD_final'] = W_bnk['W_bnk_PRE_NHD_xgb']
W_bnk.loc[W_bnk['W_bnk_PRE_NHD_xgb'] >= 0, 'xgb_or_mlr'] = 'xgb'

# Export the predicted values
W_bnk =W_bnk[['COMID','REACHCODE', 'TotDASqKM_y', 'StreamOrde_y', 'W_bnk_PRE_NHD_final', 'xgb_or_mlr']]
W_bnk.to_csv('./ModelApplication/Output/W_bnk_NHD_reaches.txt')
